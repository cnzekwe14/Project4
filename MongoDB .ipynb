# %%
#import dependencies
import pymongo
import pandas as pd
import json

# %%
# Module used to connect Python with MongoDB
from pymongo import MongoClient

# %%
## Create an instance of MongoClient and connect with localhost
mongo = pymongo.MongoClient("mongodb://localhost:27017")

# %%
#read the CSV file
df = pd.read_csv("Resources/data_df.csv")

# %%
df.head()
# Out:
#    unnamed: 0        userid         username  following  followers  \
# 0           0  1.732126e+08   JoeMokolobetsi        219        197
# 1           1  3.350414e+08  XclusivasPuebla       1419       6402
# 2           2  1.512400e+18  ShelterAnimalUA        782        109
# 3           3  1.356630e+18  DogandCatHelpe1          5         39
# 4           4  2.029712e+07   ElMananaOnline       2269      17978
#
#    totaltweets usercreatedts       tweetid  tweetcreatedts  retweetcount  ...  \
# 0         4789       09:22.0  1.560420e+18  8/19/2022 0:00             0  ...
# 1        70267       02:24.0  1.560420e+18  8/19/2022 0:00             0  ...
# 2         1198       02:47.0  1.560420e+18  8/19/2022 0:00             0  ...
# 3          690       57:12.0  1.560420e+18  8/19/2022 0:00             0  ...
# 4        56188       32:49.0  1.560420e+18  8/19/2022 0:00             0  ...
#
#                                             hashtags language favorite_count  \
# ...

# %%
df.tail()
# Out:
#        unnamed: 0        userid         username  following  followers  \
# 47989       47989  1.553460e+18        Ksana_tt_        237        157
# 47990       47990  1.329078e+08        krishtopa        687        488
# 47991       47991  1.444509e+07     El_Ciudadano      71965     553230
# 47992       47992  1.382090e+18   ElCiudadano_Mx        461       1109
# 47993       47993  2.432661e+08  TheBrianHopkins       1423       3325
#
#        totaltweets usercreatedts       tweetid   tweetcreatedts  retweetcount  \
# 47989           51       22:33.0  1.560780e+18  8/19/2022 23:59             2
# 47990        23608       01:46.0  1.560780e+18  8/19/2022 23:59             0
# 47991       226276       43:02.0  1.560780e+18  8/19/2022 23:59             0
# 47992        30631       57:41.0  1.560780e+18  8/19/2022 23:59             0
# 47993         1904       36:18.0  1.560780e+18  8/19/2022 23:59             3
#
# ...

# %%
#print the shape(rows and columns)
df.shape
# Out:
# (47994, 21)

# %%
#convert the CSV file into JSON
data = df.to_dict(orient="records")

# %%
data
# Out:
# [{'unnamed: 0': 0,
#   'userid': 173212647.0,
#   'username': 'JoeMokolobetsi',
#   'following': 219,
#   'followers': 197,
#   'totaltweets': 4789,
#   'usercreatedts': '09:22.0',
#   'tweetid': 1.56042e+18,
#   'tweetcreatedts': '8/19/2022 0:00',
#   'retweetcount': 0,
#   'text': 'Dear vaccine advocate\n\nDo take the COVID19 mRNA shot and boosters, but do know that @OurWorldInData data shows it offers zero protection, actually accelerates death of vaccinated.\n\nRegards\n#Pfizer #AstraZeneca #Moderna #NWO #Agenda2030 #COP27 #Biden #Obama #Trudeau #Jacinda #life https://t.co/VTbfuqiDvu',
# ...

# %%
#creat the 'twitterSentimentAnalysis' mongodb
mongodb = mongo["twitterSenitmentAnalysis"]

# %%
#print the details and confirmation of the mongodb
print(mongodb)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'twitterSenitmentAnalysis')

# %%
# Insert the data into the 'sentimentData' collection
mongodb.sentimentData.insert_many(data)
